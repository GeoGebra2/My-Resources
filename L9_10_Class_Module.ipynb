# %% [markdown]
# # 1. Class

# %%
def test_type(x):
    print(type(x))


test_type(123)
test_type(12.3)
test_type("123")
test_type([1, 2, 3])
test_type(print)
test_type(test_type)

my_func = print  # no () after print
my_func("Hello world")

my_func = len
my_func([1, 2, 3])

my_func = test_type
my_func({1: 2})
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'list'>
# <class 'builtin_function_or_method'>
# <class 'function'>
# Hello world
# <class 'dict'>

# %%
class Empty:
    pass


e = Empty()

print(e)
print(type(e))
print(id(e))
# Out:
# ...
# <class '__main__.Empty'>
# 2040830173200

# %%
a = int()
b = float()
c = str()
d = list()
e = tuple()
f = dict()
g = set()

print(a, b, c, d, e, f, g)
# Out:
# 0 0.0  [] () {} set()

# %%
c = str("Class and Object")
print(c.upper(), c.lower())
l = [123, 3.14, [1, 1, 1]]
print(l)
l.reverse()
print(l)
# Out:
# CLASS AND OBJECT class and object
# [123, 3.14, [1, 1, 1]]
# [[1, 1, 1], 3.14, 123]

# %%
class Empty:
    pass


def test_id(a, b, c):
    print("{} {} {}".format(id(a), id(b), id(c)))


e1 = Empty()

e1.a = 1
e1.b = 1
e1.c = 1

e2 = Empty()

e2.a = 1
e2.b = 1
e2.c = 1

a, b, c = 1, 1, 1
test_id(a, b, c)
test_id(e1.a, e1.b, e1.c)
test_id(e2.a, e2.b, e2.c)
# Out:
# 140724940235560 140724940235560 140724940235560
# 140724940235560 140724940235560 140724940235560
# 140724940235560 140724940235560 140724940235560

# %%
e1 = Empty()

e1.a = [1]
e1.b = [1]
e1.c = [1]

e2 = Empty()

e2.a = [1]
e2.b = [1]
e2.c = [1]

a, b, c = [1], [1], [1]
test_id(a, b, c)
test_id(e1.a, e1.b, e1.c)
test_id(e2.a, e2.b, e2.c)
# Out:
# 2040828686784 2040828599232 2040830170880
# 2040828688768 2040828689792 2040830108864
# 2040830094848 2040830108288 2040830100992

# %%
# e3 = Empty()
# test_id(e3.a, e3.b, e3.c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\L9_10_Class_Module.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/d%3A/L9_10_Class_Module.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> e3 = Empty()
# ----> <a href='vscode-notebook-cell:/d%3A/L9_10_Class_Module.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> test_id(e3.a, e3.b, e3.c)
#
# AttributeError: 'Empty' object has no attribute 'a'

# %%
class Dog:
    def __init__(self, color):
        self.color = color

    def bite(self, sex):
        print(f"The {sex} {self.color} dog bites you.")


black_dog = Dog("black")
white_dog = Dog("white")

black_dog.bite("male")
white_dog.bite("female")
# Out:
# The male black dog bites you.
# The female white dog bites you.

# %%
class TestInit:
    def __init__(self):
        print("__init__() is called automatically")
        print("self id: {}".format(id(self)))
        print("__init__() exit")


test1 = TestInit()
print(id(test1))

test2 = TestInit()
print(id(test2))
# Out:
# __init__() is called automatically
# self id: 2040830321872
# __init__() exit
# 2040830321872
# __init__() is called automatically
# self id: 2040830327952
# __init__() exit
# 2040830327952

# %%
class Point:
    def __init__(self, x, y):
        self.x, self.y = x, y


def print_point_id(pt):
    print(id(pt), id(pt.x), id(pt.y))


def print_point(pt):
    print(pt.x, pt.y)


pt1 = Point(3, 4)
pt2 = Point(3, 4)
print_point(pt1)
print_point(pt2)
print_point_id(pt1)
print_point_id(pt2)

print(pt1.x * pt2.y - pt1.y * pt2.x, pt1.x + pt2.y)
pt1.x = -1
pt2.y = "Hello"

print_point(pt1)
print_point(pt2)


pt1 = Point([1], [2])
pt2 = Point([1], [2])
print_point_id(pt1)
print_point_id(pt2)
# Out:
# 3 4
# 3 4
# 2040830165840 140724940235624 140724940235656
# 2040835624272 140724940235624 140724940235656
# -7 7
# -1 4
# 3 Hello
# 2040835627024 2040835704256 2040830225664
# 2040830165840 2040835703232 2040830175616

# %%
class Point:
    def __init__(self, x=0, y=0):
        self.x, self.y = x, y


pt1 = Point(3, 4)
print(pt1.x, pt1.y)

pt2 = Point()
print(pt2.x, pt2.y)
# Out:
# 3 4
# 0 0

# %%
class Dog:
    def __init__(self, name, color, age, weight):
        self.name = name
        self.color = color
        self.age = age
        self.weight = weight


def print_dog(dog):
    print(
        f"Name: {dog.name}, color: {dog.color}, age: {dog.age}, weight: {dog.weight}."
    )


dog = Dog("Fox", "Red", 3, 4)
print_dog(dog)

dog.age += 1
dog.weight /= 2
print_dog(dog)


def train_dog(dog):
    dog.name += " 1st"


train_dog(dog)
print_dog(dog)
# Out:
# Name: Fox, color: Red, age: 3, weight: 4.
# Name: Fox, color: Red, age: 4, weight: 2.0.
# Name: Fox 1st, color: Red, age: 4, weight: 2.0.

# %%
class Dog:
    def __init__(self, name, color, age, weight):
        self.name = name
        self.color = color
        self.age = age
        self.weight = weight

    def set_name(self, name):
        self.name = name

    def set_color(self, color):
        self.color = color

    def set_age(self, age):
        self.age = age

    def set_weight(self, weight):
        self.weight = weight

    def print_dog(self):
        print(
            f"Name: {self.name}, color: {self.color}, age: {self.age}, weight: {self.weight}."
        )


dg = Dog("Fox", "Red", 3, 4)
dg.print_dog()

dg.set_name("Tiger")
dg.set_color("White")
dg.set_age(10)
dg.set_weight(23)
dg.print_dog()

dg.name = "Kitty"
dg.color = "Pink"
dg.age = 2
dg.weight = 4
dg.print_dog()
# Out:
# Name: Fox, color: Red, age: 3, weight: 4.
# Name: Tiger, color: White, age: 10, weight: 23.
# Name: Kitty, color: Pink, age: 2, weight: 4.

# %%
class Test:
    def __init__(self, x=0):
        self.x = x

    def add(u, v):
        return u + v

    def inc(self):
        self.x = self.add(self.x, 1)

    def print(self):
        print(self.x)


test = Test(111)
test.print()

test.inc()
test.print()
# Out:
# 111
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\L9_10_Class_Module.ipynb Cell 15 line 1
#      <a href='vscode-notebook-cell:/d%3A/L9_10_Class_Module.ipynb#X20sZmlsZQ%3D%3D?line=14'>15</a> test = Test(111)
#      <a href='vscode-notebook-cell:/d%3A/L9_10_Class_Module.ipynb#X20sZmlsZQ%3D%3D?line=15'>16</a> test.print()
# ---> <a href='vscode-notebook-cell:/d%3A/L9_10_Class_Module.ipynb#X20sZmlsZQ%3D%3D?line=17'>18</a> test.inc()
#      <a href='vscode-notebook-cell:/d%3A/L9_10_Class_Module.ipynb#X20sZmlsZQ%3D%3D?line=18'>19</a> test.print()
#
# d:\L9_10_Class_Module.ipynb Cell 15 line 9
#       <a href='vscode-notebook-cell:/d%3A/L9_10_Class_Module.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a> def inc(self):
# ----> <a href='vscode-notebook-cell:/d%3A/L9_10_Class_Module.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a>     self.x = self.add(self.x, 1)
#
# ...

# %%
class Test:
    def __init__(self, x=0):
        self.x = x

    def add(u, v):
        return u + v

    def inc(self):
        self.x = Test.add(self.x, 1)

    def print(self):
        print(self.x)


test = Test(111)
test.print()

test.inc()
test.print()

print(Test.add(1, 1))
print(Test.add(3, 4))
# Out:
# 111
# 111
# 2
# 7

# %%
class Triangle:
    def __init__(self, a=0, b=0, c=0):
        self.a, self.b, self.c = a, b, c

# %%
tr1 = Triangle(1, 1, 1)
tr2 = Triangle()
print(f"Tr1: {tr1.a}, {tr1.b}, {tr1.c}")
print(f"Tr2: {tr2.a}, {tr2.b}, {tr2.c}")
tr1.a, tr1.b, tr1.c = 4, 3, 5
tr2.a, tr2.b, tr2.c = 4, 3, 3
print(f"Tr1: {tr1.a}, {tr1.b}, {tr1.c}")
print(f"Tr2: {tr2.a}, {tr2.b}, {tr2.c}")
# Out:
# Tr1: 1, 1, 1
# Tr2: 0, 0, 0
# Tr1: 4, 3, 5
# Tr2: 4, 3, 3

# %%
class Triangle:
    def __init__(self, a=0, b=0, c=0):
        self.a, self.b, self.c = a, b, c

    def is_valid(self):
        return (
            self.a > 0
            and self.b > 0
            and self.c > 0
            and self.a + self.b > self.c
            and self.b + self.c > self.a
            and self.c + self.a > self.b
        )

    def set_edges(self, a, b, c):
        self.a, self.b, self.c = a, b, c

    def area(self):
        q = (self.a + self.b + self.c) / 2
        return (q * (q - self.a) * (q - self.b) * (q - self.c)) ** 0.5

    def print(self):
        print(f"Triangle: {self.a}, {self.b}, {self.c}")

    def print_area(self):
        print(f"Area: {self.area():.3f}")  # area()会报错, 必须加self

# %%
t1 = Triangle()
t1.set_edges(3, 4, 5)

if t1.is_valid():
    t1.print()
    t1.print_area()
# Out:
# Triangle: 3, 4, 5
# Area: 6.000

# %%
class HappyNumber:
    def __init__(self, number):
        self.number = number

    def sum_of_digit_squares(self):
        return sum([int(x) ** 2 for x in str(self.number)])  # self is needed

    def print_HN(self):
        print(self.number)

    def is_happy(self):
        if self.number == 1:
            return True

        loop = {self.number}
        while loop:
            nn = self.sum_of_digit_squares()
            if nn == 1:
                print(loop)
                return True

            if nn in loop:
                print(loop)
                return False

            loop.add(nn)
            self.number = nn
            


hn = HappyNumber(1234567890987654321)
hn.print_HN()
print(hn.sum_of_digit_squares())
print(hn.is_happy())

hn = HappyNumber(19)
hn.print_HN()
print(hn.sum_of_digit_squares())
print(hn.is_happy())

hn = HappyNumber(2)
hn.print_HN()
print(hn.sum_of_digit_squares())
print(hn.is_happy())
# Out:
# 1234567890987654321
# 570
# {65, 58, 37, 4, 74, 42, 16, 1234567890987654321, 145, 20, 89, 570, 61}
# False
# 19
# 82
# {100, 82, 19, 68}
# True
# 2
# 4
# {2, 4, 37, 42, 16, 145, 20, 89, 58}
# False

# %%
def area(a, b, c):
    q = (a + b + c) / 2
    return (q * (q - a) * (q - b) * (q - c)) ** 0.5


class Test:
    def __init__(self, a=0, b=0, c=0):
        self.a, self.b, self.c = a, b, c

    def area(self):
        return area(self.a, self.b, self.c)


print("test")
a, b, c = 3, 4, 5
print(area(a, b, c))
test = Test(3, 3, 3)
print(test.area())

# %%
def area(a, b, c):
    q = (a + b + c) / 2
    return (q * (q - a) * (q - b) * (q - c)) ** 0.5


class Test1:
    def area(self):
        return area(self.a, self.b, self.c)

    def print(self):
        print(f"Triangle: {self.a}, {self.b}, {self.c}")


t1 = Test1()
t1.a, t1.b, t1.c = 1.1, 2.1, 1.1
t1.print()
print(t1.area())
# Out:
# Triangle: 1.1, 2.1, 1.1
# 0.34426552252585607

# %%
class SomeClass:
    variable_1 = ["This is a class variable", 2018]
    variable_2 = 100  # this is also a class variable.

    def __init__(self, param1, param2):
        self.instance_var1 = param1
        # instance_var1 is a instance variable
        self.instance_var2 = param2
        # instance_var2 is a instance variable


obj1 = SomeClass("some thing", 18)
obj2 = SomeClass(28, 6)

print(obj1.variable_1, id(obj1.variable_1))
print(obj2.variable_2, id(obj2.variable_2))
print(obj1.instance_var1)
print(obj2.instance_var2)
# Out:
# ['This is a class variable', 2018] 2040836444480
# 100 140724940238728
# some thing
# 6

# %%
class ClassVariable:
    number = 3

    def __init__(self):
        print("init")
        ClassVariable.number += 1  # don"t use self
        self.x = 1

    @classmethod
    def print_num(cls):
        print(cls.number)

    @classmethod
    def add_x(cls):
        cls.number += 1


print(ClassVariable.number)
ClassVariable.print_num()
ClassVariable.add_x()
print(ClassVariable.number)

#v1 = ClassVariable()
#print(ClassVariable.number, v1.number, v1.x)
#v1.add_x()
#print(ClassVariable.number, v1.x, v1.number)
#v2 = ClassVariable()
#print(ClassVariable.number, v2.number, v2.x, v1.number, v1.x)
#v3 = ClassVariable()
#print(ClassVariable.number, v3.number, v3.x)
#print(v1.x, v2.number, v3.x)

#print(ClassVariable.number)
#ClassVariable.print_num()
# Out:
# 3
# 3
# 4

# %%
class SomeClassA:
    def create_arr(self):  # An instance method
        self.arr = []

    def insert_to_arr(self, value):  # An instance method
        self.arr.append(value)

    @classmethod
    def class_method(cls):
        print("the class method was called")


SomeClassA.class_method()
# Out:
# the class method was called
# Test 1
# Test 2
# Test 3

# %%
class Example:
    cnt = 3

    @classmethod
    def class_method(cls):
        print("Test", cls.cnt)

Example.class_method()
Example.class_method()
Example.class_method()
# Out:
# Test 3
# Test 3
# Test 3

# %%
class Person:
    def __init__(self, name, job=None, pay=0):
        print("Init: Person " + name)
        self.name = name
        self.job = job
        self.pay = pay

    def get_last_name(self):
        return self.name.split()[-1]

    def give_raise(self, percent):
        self.pay = int(self.pay * (1 + percent))

    def __repr__(self):  # added method
        return f"[Person: {self.name}, {self.pay}]"  # string to print

class Manager(Person):
    pass


roger = Manager("Roger Chen", "Manager", 100000)
print(roger.name, roger.job, roger.pay)
print(roger.get_last_name())
roger.give_raise(percent=0.2)
print(roger)
# Out:
# Init: Person Roger Chen
# Roger Chen Manager 100000
# Chen
# [Person: Roger Chen, 120000]

# %%
class Ape:
    pass


class Human(Ape):
    pass


class Chinese(Human):
    pass


class Greece(Human):
    pass


class Students(Greece, Chinese):
    pass


stt = Students()
print(type(stt))

# %%
def func1(name, age):
    print(f"name = {name}, age = {age}")


func1("Hello", 28)


def func1(name, age, country):
    print(f"name = {name}, age = {age}, country = {country}")


# func1("Hello", 28) # error
func1("Hello", 28, "CN")

# %%
class Manager(Person):
    def give_raise(self, percent, bonus=0.1):
        Person.give_raise(self, percent + bonus)
        # self.pay = int(self.pay * (1+percent)) # Bad: cut and paste
        # double maintance

    def __repr__(self):  # added method
        return "[Manager: {:s} {:d}]".format(self.name, self.pay)  # string to print


roger = Manager("Roger Chen", "Manager", 100000)
print(roger)
roger.give_raise(percent=0.1)
print(roger)
# Out:
# Init: Person Roger Chen
# [Manager: Roger Chen 100000]
# [Manager: Roger Chen 120000]

# %%
class Manager(Person):
    def __init__(self, name, pay, id):
        print("Init: Manager " + name)
        Person.__init__(self, name, "manager", pay)
        self.id = id

    def give_raise(self, percent, bonus=0.1):
        Person.give_raise(self, percent + bonus)

    def __repr__(self):
        return f"[Manager: {self.name}, {self.id} {self.pay}]"


roger = Manager(name="Roger Chen", pay=100000, id="CN007")
print(roger)
print(roger.job)
roger.give_raise(percent=0.1)
print(roger)
# Out:
# Init: Manager Roger Chen
# Init: Person Roger Chen
# [Manager: Roger Chen, CN007 100000]
# manager
# [Manager: Roger Chen, CN007 120000]

# %%
print(roger.__class__)
print(roger.__class__.__name__)
print(list(roger.__dict__.keys()))

for key in roger.__dict__:
    print(key, "=>", roger.__dict__[key])

for key in roger.__dict__:
    print(roger, "=>", getattr(roger, key))
# Out:
# <class '__main__.Manager'>
# Manager
# ['name', 'job', 'pay', 'id']
# name => Roger Chen
# job => manager
# pay => 120000
# id => CN007
# [Manager: Roger Chen, CN007 120000] => Roger Chen
# [Manager: Roger Chen, CN007 120000] => manager
# [Manager: Roger Chen, CN007 120000] => 120000
# [Manager: Roger Chen, CN007 120000] => CN007

# %%
x = 100
print(dir(x))

x = "SJTU"
print(dir(x))
# Out:
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_count', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# ...

# %%
class Base(object):
    pass  # Empty Class


class Derived(Base):
    pass  # Empty Class


# Driver Code
print(issubclass(Derived, Base))
print(issubclass(Base, Derived))

d = Derived()
b = Base()

# b is not an instance of Derived
print(isinstance(b, Derived))

# But d is an instance of Base
print(isinstance(d, Base))
# Out:
# True
# False
# False
# True

# %%
L1 = [1, ("a", 3)]  # Same value, unique objects
L2 = [1, ("a", 3)]
print(L1 == L2, L1 is L2)

S1 = "spam"
S2 = "spam"
print(S1 == S2, S1 is S2)

S1 = "xyz a longer string+_)(*&^%$#@!"
S2 = "xyz a longer string+_)(*&^%$#@!"
print(S1 == S2, S1 is S2)

# %%
x = 100
y = 100
print(x == y, x is y)

x = 2**64
y = 2**64
print(x == y, x is y)

x = 2**128
y = 2**128
print(x == y, x is y)

# %%
x = "Hello"
y = "SJTU"
z = x + y
w = "HelloSJTU"

print(z is w, z == w, z)

# %%
import sys

x = str(2**1)
y = str(2**1)
print(x == y, x is y)

x = sys.intern(x)
y = sys.intern(y)
print(x is y, x == y, x)

# %%
def printer(str1):
    print("Hello, world")


print(dir(printer))
print(type(printer))
print(printer.__module__)
print(printer.__name__)

# %%
class Triangle:
    def __init__(self, a=0, b=0, c=0):
        self.a, self.b, self.c = a, b, c

    def is_valid(self):
        return (
            self.a > 0
            and self.b > 0
            and self.c > 0
            and self.a + self.b > self.c
            and self.b + self.c > self.a
            and self.c + self.a > self.b
        )

    def set_edges(self, a, b, c):
        self.a, self.b, self.c = a, b, c

    def area(self):
        q = (self.a + self.b + self.c) / 2
        return (q * (q - self.a) * (q - self.b) * (q - self.c)) ** 0.5

    def print(self):
        print("Triangle: {self.a}, {self.b}, {self.c}")

    def print_area(self):
        print("Area: {:.3f}".format(self.area()))  # area()会报??, 必须加self

    def __len__(self):
        return self.a + self.b + self.c

    def __str__(self):
        return ", ".join((str(self.a), str(self.b), str(self.c)))

    def __lt__(self, other):  # x<y                   lt: large than
        return self.a < other.a and self.b < other.b and self.c < other.c

    def __le__(self, other):  # x<=y                 less equal
        return self.a <= other.a and self.b <= other.b and self.c <= other.c

    def __eq__(self, other):  # x==y                 equal
        return self.a == other.a and self.b <= other.b and self.c <= other.c

    def __ne__(self, other):  # x!=y                   not equal
        return self.a != other.a or self.b != other.b or self.c != other.c

    def __gt__(self, other):  # x>y                   greater than
        return self.a > other.a and self.b > other.b and self.c > other.c

    def __ge__(self, other):  # x>=y                 greater equal
        return self.a >= other.a and self.b >= other.b and self.c >= other.c

# %%
t = Triangle()
t.set_edges(3, 4, 5)
print(len(t))
print(t)

t1 = Triangle()
t1.set_edges(3, 4, 5)
print("<     <=   !=    ==    >    >=")
print(t < t1, t <= t1, t != t1, t == t1, t > t1, t >= t1)

t1 = Triangle()
t1.set_edges(4, 5, 6)
print("<     <=   !=    ==    >    >=")
print(t < t1, t <= t1, t != t1, t == t1, t > t1, t >= t1)
# Out:
# 12
# 3, 4, 5
# <     <=   !=    ==    >    >=
# False True False True False True
# <     <=   !=    ==    >    >=
# True True True False False False

# %%
class vector:
    def __init__(self, n):
        self.data = [1] * n

    def __getitem__(self, index):
        return self.data[index]

    def __setitem__(self, index, value):
        self.data[index] = value


v = vector(100)
v.data = [i for i in range(100)]
print(v[67])
v[67] = -100
print(v[67])
# Out:
# 67
# -100

# %%
class Number:
    def __init__(self, start):
        self.data = start

    def __add__(self, other):
        return Number(self.data + other)

    def __radd__(self, other):
        return Number(self.data + other)

    def __iadd__(self, other):  # __iadd__ explicit: x += y
        self.data += other  # Usually returns self
        return self

    def __str__(self):
        return str(self.data)


x = Number(1)
print(x)
y = x + 1
z = -9 + x
x += 100
print(x, y, z)

# %%
class A:
    attrA = "A"


class B:
    attrB = "B"


class C(A, B):
    attrC = "C"


x = C()
print(x.attrA, x.attrB, x.attrC)

# %%
class A1:
    attr = "A1"


class A2:
    attr = "A2"


class A3(A1, A2):
    attr = "A3"


x = A3()
print(x.attr)

# %%
class A:
    attr = "A"


class B(A):
    attr = "B"


class C(A):
    attr = "C"


class D(B, C):
    pass


x = D()
print(x.attr)

# %%
class A:
    attr = "A"


class B(A):
    attr = "B"


class C(A):
    attr = "C"


class D(C, B):
    pass


x = D()
print(x.attr)

# %%
s = "Hello world"
print(str(s), repr(s))

print(2.0 / 11.0, repr(2.0 / 11.0))

import datetime

today = datetime.datetime.now()

print(str(today))
print(repr(today))

# %%
def f(x, y):
    print(f"values: {x} {y}")


f(42, 43)
f(42, 43.7)
f(42.3, 43)
f(42.0, 43.9)

# %%
def printer(x):
    print(x)


bob = Person("Bob Smith")
sue = Person("Sue Jones", job="dev", pay=100000)
roger = Manager("Roger Chen", "manager", 100000)
printer(1)
printer("SJTU")
printer(list(range(4)))
printer(bob)
printer(sue)
printer(roger)

# %% [markdown]
# # 2. Module

# %%
import b

b.spam("Test")
# Out:
# Test spam

# %%
import my_geometry

tt = my_geometry.Triangle(6, 7, 8)
tt.print()
print(my_geometry.__name__)
# Out:
# my_geometry.Triangle: 6, 7, 8
# my_geometry

# %%
import module1

module1.printer([1, 2, 4])
# Out:
# [1, 2, 4]

# %%
print("Enter module1.py")  # module1.py

name = "SJTU"


def printer(x):
    print(x)


print(name)
print("Exit module1.py")
# Out:
# Enter module1.py
# SJTU
# Exit module1.py

# %%
def printer(str):
    print(f"print main {str}")

from module1 import printer


printer("test")
# Out:
# test

# %%
import simple

print(simple.spam)

simple.spam = 2

import simple

print(simple.spam)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\L9_10_Class_Module.ipynb 单元格 58 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/L9_10_Class_Module.ipynb#Y112sZmlsZQ%3D%3D?line=0'>1</a> import simple
#       <a href='vscode-notebook-cell:/d%3A/L9_10_Class_Module.ipynb#Y112sZmlsZQ%3D%3D?line=2'>3</a> print(simple.spam)
#       <a href='vscode-notebook-cell:/d%3A/L9_10_Class_Module.ipynb#Y112sZmlsZQ%3D%3D?line=4'>5</a> simple.spam = 2
#
# ModuleNotFoundError: No module named 'simple'

# %%
import module1

module1.printer([1, 2, 4])
# Out:
# [1, 2, 4]

# %%
print("Enter module1.py")  # module1.py

name = "SJTU"


def printer(x):
    print(x)


print(name)
print("Exit module1.py")

if __name__ == "__main__":
    print("module1 main")
# Out:
# Enter module1.py
# SJTU
# Exit module1.py
# module1 main

# %% [markdown]
# # 3. Interpreter

# %%
# lec2.py
def add(x, y):
	return x*y + x + y

# %%
# lec3.py
import lec2


def add(x, y):
    return x * y - x - y


print(lec2.add(1, 2))
print(lec2.add(-1, 1))
print(lec2.add(3.1, 2.7))

print(add(1, 2))
print(add(-1, 1))
print(add(3.1, 2.7))

# %%
# lec4.py
import lec2
import lec3


def add(x, y):
    return x + y


print(lec2.add(1, 2))
print(lec2.add(-1, 1))
print(lec2.add(3.1, 2.7))

print(lec3.add(1, 2))
print(lec3.add(-1, 1))
print(lec3.add(3.1, 2.7))


print(add(1, 2))
print(add(-1, 1))
print(add(3.1, 2.7))

# %%
import py_compile

py_compile.compile("lec4.py")

# %%
import compileall

compileall.compile_dir(".")

# %%
import dis


def hello():
    print("Hello, World!")


dis.dis(hello)

print(hello.__code__)
print(hello.__code__.co_consts)
print(hello.__code__.co_varnames)
print(hello.__code__.co_names)
