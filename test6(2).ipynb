# %%
import minimatrix as mm
import numpy as np

#test6
m = 100
n = 10
X = mm.nrandom((m, n))
w = mm.nrandom((n, 1))
e = mm.nrandom((m, 1))
e = mm.zero_mean(e)
Y = X.dot(w) + e
X_T = X.T()
A = X_T.dot(X)
for x in range(A.dim[0]):
    for y in range(A.dim[1]):
        A.data[x][y] = round(A.data[x][y], 5)
        
print("Original A")
print(A)
inv_A_1 = A.inverse_1()
print("After inv1")
print(A)
inv_A_2 = A.inverse_2()
print("after inv2")
print(A)
print(A.data[0][3])
print(inv_A_1)
print(inv_A_2)
#B = inv_A.dot(X_T)
#w_ = B.dot(Y)
#print(w_)
#print(w)
#print(w - w_)
# Out:
# Original A
# [[33.5470325.1746225.1167926.5866525.0467127.4948924.6856224.9295323.2078425.54195]
#  [25.1746234.392324.2585226.892224.4831627.8713526.4463224.6810723.7656225.57777]
#  [25.1167924.2585233.7170326.3302622.9022727.1834325.8148226.0552223.1646927.14795]
#  [26.5866526.892226.3302638.0991127.8206729.966226.69528.9866724.87128.05038]
#  [25.0467124.4831622.9022727.8206732.7477725.8089125.0591524.7656722.2526224.64735]
#  [27.4948927.8713527.1834329.966225.8089138.1492426.5373529.5819925.0241626.61343]
#  [24.6856226.4463225.8148226.69525.0591526.5373534.0282826.0604223.1448725.97422]
#  [24.9295324.6810726.0552228.9866724.7656729.5819926.0604234.1948524.2609526.96422]
#  [23.2078423.7656223.1646924.87122.2526225.0241623.1448724.2609530.3863524.38647]
#  [25.5419525.5777727.1479528.0503824.6473526.6134325.9742226.9642224.3864735.26482]]
# After inv1
# [[33.5470325.1746225.1167926.5866525.0467127.4948924.6856224.9295323.2078425.54195]
# ...
