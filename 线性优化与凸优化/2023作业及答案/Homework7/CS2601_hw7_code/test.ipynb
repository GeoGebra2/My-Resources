# %%
import numpy as np
from copy import deepcopy

# %%
c =  np.array([-1.0, -3.0, 0.0, 0.0])
A =  np.array([[2.0, 1.0, 1.0 ,0.0],[-1.0, 2.0, 0.0, 1.0]])
b =  np.array([8, 6])

x0 =  np.array([2.0, 1.0, 3.0, 7.0])

# %%
t = 1.0
def f(x):
    return c.T @ x - 1.0/t * sum(np.log(x))

def fp(x):
    return c - 1.0/(t * x)

def fpp(x):
    return np.diag(1.0/(x**2 * t))

# %%
np.log(0.0)
# Out:
# d:\rayfiles\Anaconda\envs\seq2seq\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# -inf
